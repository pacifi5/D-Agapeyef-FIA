# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15436\3543044481.py in ?()
#       6 X = cipher_data.drop(columns=['Cipher'])
#       7 y = cipher_data['Cipher']
#       8
#       9 model = DecisionTreeClassifier()
# ---> 10 model.fit(X,y)
#      11 labelEnc = LabelEncoder()
#      12 cipher = 'dlgc mq cs ywexsre s hgnrr dlgxo gd amepb reto ambocn er kpj'
#      13 cipher = labelEnc.fit_transform(cipher)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ...
